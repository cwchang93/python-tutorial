# %% [markdown]
# # Lesson 09–10 課前複習
#
# 複習錯誤處理、函式、模組、Path、文字檔與 CSV。
#
# > 請讓 `lesson10_sales.csv` 與 Notebook 保持在同一個資料夾。

# %% [markdown]
# ## Lesson 09｜題目 1：辨識錯誤類型
#
# 請說明 `int('abc')` 會產生哪一種錯誤。

# %%
# 請填寫錯誤類型

# %% [markdown]
# ## Lesson 09｜題目 2：安全轉換整數
#
# 用 `try/except` 處理文字轉整數失敗。

# %%
text = 'abc'
# 請完成

# %% [markdown]
# ## Lesson 09｜題目 3：處理除以零
#
# 安全計算 `100 / people`。

# %%
people = 0
# 請完成

# %% [markdown]
# ## Lesson 09｜題目 4：多種錯誤
#
# 分開處理 ValueError 與 IndexError。

# %%
values = ['10', '20']
index = 'x'
# 請完成

# %% [markdown]
# ## Lesson 09｜題目 5：成功與失敗流程
#
# 使用 `else` 顯示成功結果。

# %%
text = '88'
# 請完成

# %% [markdown]
# ## Lesson 09｜題目 6：一定執行的收尾
#
# 使用 `finally` 印出「處理結束」。

# %%
# 請完成 try/finally

# %% [markdown]
# ## Lesson 09｜題目 7：驗證分數範圍
#
# 分數不在 0～100 時提出 ValueError。

# %%
score = 120
# 請完成

# %% [markdown]
# ## Lesson 09｜題目 8：整理錯誤資料
#
# 逐筆轉換分數，錯誤資料放入 `errors`。

# %%
raw_scores = ['90', 'abc', '75']
# 請完成

# %% [markdown]
# ## Lesson 10｜題目 9：使用 math
#
# 使用 `math.sqrt()` 計算 81 的平方根。

# %%
# 請完成

# %% [markdown]
# ## Lesson 10｜題目 10：使用 Path
#
# 建立 `data/report.csv` 路徑。

# %%
# 請完成

# %% [markdown]
# ## Lesson 10｜題目 11：寫入文字檔
#
# 使用 `with open` 寫入兩行文字。

# %%
# 請完成

# %% [markdown]
# ## Lesson 10｜題目 12：讀取文字檔
#
# 讀取檔案並逐行印出，去除換行。

# %%
# 請完成

# %% [markdown]
# ## Lesson 10｜題目 13：讀取 CSV
#
# 用 `csv.DictReader` 讀取課程提供的 `lesson10_sales.csv`。

# %%
from pathlib import Path
csv_path = Path('lesson10_sales.csv')
# 請完成

# %% [markdown]
# ## Lesson 10｜題目 14：CSV 數字轉換
#
# 將 `quantity` 與 `unit_price` 轉成數字。

# %%
row = {'quantity': '3', 'unit_price': '120'}
# 請完成

# %% [markdown]
# ## Lesson 10｜題目 15：計算 CSV 總額
#
# 逐筆計算 `quantity * unit_price`。

# %%
from pathlib import Path
csv_path = Path('lesson10_sales.csv')
# 請完成

# %% [markdown]
# ## Lesson 09–10｜題目 16：安全 CSV 摘要
#
# 讀取銷售 CSV，遇到錯誤資料時記錄錯誤，最後輸出總額與錯誤筆數。

# %%
from pathlib import Path
csv_path = Path('lesson10_sales.csv')
# 請整合 try/except、Path、csv、for 與函式
