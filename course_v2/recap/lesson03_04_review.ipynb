# %% [markdown]
# # Lesson 03–04 課前複習
#
# 先複習條件判斷，再複習 List 與 Tuple。每題先猜結果，再執行。

# %% [markdown]
# ## Lesson 03｜題目 1：及格判斷
# 分數大於等於 60 顯示及格，否則顯示需要補強。

# %%
score = 72
# 請完成

# %% [markdown]
# ## Lesson 03｜題目 2：奇偶數
# 判斷 number 是奇數還是偶數。

# %%
number = 17
# 請完成

# %% [markdown]
# ## Lesson 03｜題目 3：溫度提醒
# 低於 18 偏冷、18～27 舒適、其他偏熱。

# %%
temperature = 25
# 請完成

# %% [markdown]
# ## Lesson 03｜題目 4：會員折扣
# 會員且消費滿 1000 元打 9 折，否則原價。

# %%
is_member = True
amount = 1200
# 請完成

# %% [markdown]
# ## Lesson 03｜題目 5：外送費
# 本島滿 800 免運，未滿收 80；離島固定收 150。

# %%
region = '本島'
amount = 650
# 請完成

# %% [markdown]
# ## Lesson 03｜題目 6：成績是否通過
# 平時與考試分數都至少 60 才通過。

# %%
homework = 75
exam = 62
# 請完成

# %% [markdown]
# ## Lesson 03｜題目 7：ATM 提款
# 餘額足夠且提款金額是 100 的倍數才允許提款。

# %%
balance = 3000
withdraw = 1200
# 請完成

# %% [markdown]
# ## Lesson 03｜題目 8：電量提醒
# 低於 20 充電；20～79 普通；80 以上充足。

# %%
battery = 65
# 請完成

# %% [markdown]
# ## Lesson 04｜題目 9：索引與負索引
# 印出第一筆、最後一筆與清單長度。

# %%
courses = ['Python', 'Excel', 'SQL']
# 請完成

# %% [markdown]
# ## Lesson 04｜題目 10：切片
# 取得前兩筆、最後兩筆與反轉後的清單。

# %%
numbers = [10, 20, 30, 40, 50]
# 請完成

# %% [markdown]
# ## Lesson 04｜題目 11：購物車增刪
# 新增雞蛋、插入牛奶到最前面，移除麵包。

# %%
cart = ['麵包', '水果']
# 請完成

# %% [markdown]
# ## Lesson 04｜題目 12：候位叫號
# 用 pop(0) 取出第一位客人，印出叫號與剩餘名單。

# %%
queue = ['Amy', 'Bob', 'Cindy']
# 請完成

# %% [markdown]
# ## Lesson 04｜題目 13：List 運算
# 用 + 合併行程，用 * 產生三次提醒。

# %%
morning = ['早餐', '通勤']
afternoon = ['上課', '運動']
reminder = ['記得喝水']
# 請完成

# %% [markdown]
# ## Lesson 04｜題目 14：copy 與 alias
# 建立 alias 與 copied，觀察修改後的差異。

# %%
shopping = ['牛奶', '麵包']
# 請完成

# %% [markdown]
# ## Lesson 04｜題目 15：Tuple 拆包
# 將座標 Tuple 拆成 latitude 與 longitude。

# %%
point = (25.0330, 121.5654)
# 請完成

# %% [markdown]
# ## Lesson 04｜題目 16：List 還是 Tuple？
# 為會變動的待辦事項與固定 RGB 顏色選擇資料型別。

# %%
# 建立 tasks 與 brand_color
