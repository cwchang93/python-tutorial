# %% [markdown]
# # Lesson 01–02 課前複習
#
# 每題先猜結果，再執行驗證。請在下一個 Code cell 完成。

# %% [markdown]
# ## 題目 1｜印出 Hello Python
# 使用 `print()` 印出 `Hello, Python!`。

# %%
# 請完成

# %% [markdown]
# ## 題目 2｜印出兩行文字
# 印出 `第一行` 與 `第二行`。

# %%
# 請完成

# %% [markdown]
# ## 題目 3｜Interpreter
# 在 VS Code 中如何確認目前使用的 Python Interpreter？請先口頭回答，再查看右下角或 Command Palette。

# %%
# 本題為環境操作題

# %% [markdown]
# ## 題目 4｜註解
# 將下面這行改成註解，使它不會執行。

# %%
print('這行不要執行')

# %% [markdown]
# ## 題目 5｜縮排
# 修正縮排，讓程式可以執行。

# %%
if True:
print('可以執行')

# %% [markdown]
# ## 題目 6｜基本資料型態
# 建立 `name`、`age`、`height`、`is_student`，分別放入字串、整數、浮點數與布林值。

# %%
# 請完成

# %% [markdown]
# ## 題目 7｜四則運算
# 計算 `10` 與 `3` 的加法、除法、整除、餘數與次方。

# %%
a = 10
b = 3
# 請完成

# %% [markdown]
# ## 題目 8｜自我介紹
# 使用變數組合並印出：`我叫 Amy，今年 25 歲`。

# %%
# 請完成

# %% [markdown]
# ## 題目 9｜變數命名
# 判斷 `student_name`、`2nd_name`、`class`、`score2` 哪些可用，並說明原因。

# %%
# 請用註解寫下你的判斷

# %% [markdown]
# ## 題目 10｜比較運算
# 判斷 `score = 82` 是否大於等於 60，印出布林結果。

# %%
score = 82
# 請完成
