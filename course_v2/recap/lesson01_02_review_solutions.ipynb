# %% [markdown]
# # Lesson 01–02 課前複習｜講師答案
#
# 每一題先保留題目，再執行下面的參考答案。

# %% [markdown]
# ## 題目 1｜印出 Hello Python
# 使用 `print()` 印出 `Hello, Python!`。

# %%
print('Hello, Python!')

# %% [markdown]
# ## 題目 2｜印出兩行文字
# 印出 `第一行` 與 `第二行`。

# %%
print('第一行')
print('第二行')

# %% [markdown]
# ## 題目 3｜Interpreter
# 在 VS Code 中如何確認目前使用的 Python Interpreter？

# %%
# 參考：查看 VS Code 右下角的 Python 版本，或使用
# Command Palette → Python: Select Interpreter

# %% [markdown]
# ## 題目 4｜註解
# 將下面這行改成註解，使它不會執行。

# %%
# print('這行不要執行')

# %% [markdown]
# ## 題目 5｜縮排
# 修正縮排，讓程式可以執行。

# %%
if True:
    print('可以執行')

# %% [markdown]
# ## 題目 6｜基本資料型態
# 建立四種基本資料型態。

# %%
name = 'Amy'
age = 25
height = 165.5
is_student = True

# %% [markdown]
# ## 題目 7｜四則運算
# 計算 `10` 與 `3` 的加法、除法、整除、餘數與次方。

# %%
a = 10
b = 3
print(a + b)
print(a / b)
print(a // b)
print(a % b)
print(a ** 2)

# %% [markdown]
# ## 題目 8｜自我介紹
# 使用變數組合並印出自我介紹。

# %%
name = 'Amy'
age = 25
print('我叫', name, '今年', age, '歲')

# %% [markdown]
# ## 題目 9｜變數命名
# 判斷四個名稱。

# %%
# student_name：合法
# 2nd_name：不合法，不能用數字開頭
# class：保留字，不可使用
# score2：合法

# %% [markdown]
# ## 題目 10｜比較運算
# 判斷分數是否及格。

# %%
score = 82
print(score >= 60)
