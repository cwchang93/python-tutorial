# %% [markdown]
# # Lesson 10｜模組與檔案
#
# 用標準函式庫與文字檔、CSV 保存資料，為後續資料分析準備素材。

# %% [markdown]
# ## 例題 01｜CSV 銷售分析

# %%
# 讀取銷售 CSV，計算總額、平均與最高單筆。

# %% [markdown]
# ## 例題 02｜文字檔日誌

# %%
# 把每日工作紀錄附加到文字檔並統計行數。

# %% [markdown]
# ## 例題 03｜隨機抽樣報告

# %%
# 使用 random 產生樣本，輸出各類別出現次數。

# %% [markdown]
# ## 例題 04｜小型資料管線

# %%
# 建立 CSV、讀取、清理數字並輸出摘要報表。
