# %% [markdown]
# # Lesson 10｜模組與檔案
#
# 用標準函式庫與文字檔、CSV 保存資料，為後續資料分析準備素材。

# %% [markdown]
# ## 例題 01｜模組與檔案工具箱
#
# 建立一個自訂模組 `report_tools.py`，至少包含計算總額與格式化摘要兩個函式；主程式匯入後讀取課程 CSV 並輸出報表。

# %%
# 請建立 report_tools.py，並在主程式中使用 import 呼叫
# 報表至少要顯示資料筆數與銷售總額

# %% [markdown]
# ## 例題 02｜文字日誌：w 與 a
#
# 第一次執行用 w 建立日誌；第二次執行改用 a 追加內容。最後逐行讀取並移除換行。

# %%
# 請使用 with open、w、a 與逐行讀取完成

# %% [markdown]
# ## 例題 03｜隨機抽樣報告

# %%
# 使用 random 產生樣本，輸出各類別出現次數。

# %% [markdown]
# ## 例題 04｜小型資料管線

# %%
# 建立 CSV、讀取、清理數字並輸出摘要報表。
