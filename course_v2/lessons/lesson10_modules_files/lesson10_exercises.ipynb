# %% [markdown]
# # Lesson 10｜模組與檔案
#
# 用標準函式庫與文字檔、CSV 保存資料，為後續資料分析準備素材。

# %% [markdown]
# ## 例題 01｜math 平方根

# %%
# 使用 math.sqrt 計算 144 的平方根。

# %% [markdown]
# ## 例題 02｜ceil 與 floor

# %%
# 使用 math.ceil 與 math.floor 比較 4.6。

# %% [markdown]
# ## 例題 03｜統計平均

# %%
# 使用 statistics.mean 計算三筆成績平均。

# %% [markdown]
# ## 例題 04｜隨機抽籤

# %%
# 使用 random.choice 從三個名字抽出一人。

# %% [markdown]
# ## 例題 05｜日期格式

# %%
# 建立日期並輸出 YYYY/MM/DD。

# %% [markdown]
# ## 例題 06｜建立文字檔

# %%
# 建立 memo.txt 並寫入三行待辦事項。

# %% [markdown]
# ## 例題 07｜讀取文字檔

# %%
# 讀取 memo.txt 並逐行輸出。

# %% [markdown]
# ## 例題 08｜附加紀錄

# %%
# 用 append 模式新增一行。

# %% [markdown]
# ## 例題 09｜檔案存在

# %%
# 用 Path.exists 檢查資料檔。

# %% [markdown]
# ## 例題 10｜寫入 CSV

# %%
# 寫入商品、數量、價格三欄 CSV。

# %% [markdown]
# ## 例題 11｜讀取 CSV

# %%
# 讀取 CSV 並輸出每一列。

# %% [markdown]
# ## 例題 12｜CSV 小計

# %%
# 讀取數量與價格，計算總額。

# %% [markdown]
# ## 例題 13｜DictWriter

# %%
# 用 DictWriter 寫入兩筆會員資料。

# %% [markdown]
# ## 例題 14｜DictReader

# %%
# 用欄位名稱讀取會員資料。

# %% [markdown]
# ## 例題 15｜CSV 篩選

# %%
# 只輸出金額大於 1000 的列。

# %% [markdown]
# ## 例題 16｜Path 組合

# %%
# 組合 data 與 sales.csv 路徑。

# %% [markdown]
# ## 例題 17｜列出文字檔

# %%
# 用 glob 找出目前資料夾所有 txt。

# %% [markdown]
# ## 例題 18｜目前資料夾

# %%
# 用 os.getcwd 顯示工作目錄。

# %% [markdown]
# ## 例題 19｜報表日期

# %%
# 在 CSV 報表加入今天日期欄位。

# %% [markdown]
# ## 例題 20｜文字檔統計

# %%
# 讀取文字檔並計算行數。

# %% [markdown]
# ## 例題 21｜CSV 平均

# %%
# 計算 CSV 分數平均並標示最高分。

# %% [markdown]
# ## 例題 22｜random 模擬

# %%
# 產生 10 次 1～6 點骰子結果並計數。

# %% [markdown]
# ## 例題 23｜模組別名

# %%
# 使用 statistics as stats 完成平均。

# %% [markdown]
# ## 例題 24｜檔案備份

# %%
# 把文字檔內容讀出後寫入 backup.txt。

# %% [markdown]
# ## 例題 25｜綜合銷售報表

# %%
# 建立 CSV、讀回資料、計算總銷售額並輸出。
