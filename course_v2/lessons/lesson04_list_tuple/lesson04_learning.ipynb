# %% [markdown]
# # lesson04｜List 深入與 Tuple 入門
#
# 先預測、再執行，最後換資料測試。

# %% [markdown]
# ## 例題 01｜一筆資料與多筆資料
#
# 資料變多時，用 List 一起管理。

# %%
name = 'Amy'
names = ['Amy', 'Bob', 'Cindy']
print(name)
print(names)

# %% [markdown]
# ## 例題 02｜建立 List
#
# 中括號內可放多筆資料，並保留順序。

# %%
courses = ['Python', 'Excel', 'SQL']
print(courses)
print(len(courses))

# %% [markdown]
# ## 例題 03｜Index 從 0 開始
#
# 第一筆是 0，最後一筆可以用 -1。

# %%
courses = ['Python', 'Excel', 'SQL']
print(courses[0])
print(courses[1])
print(courses[-1])

# %% [markdown]
# ## 例題 04｜餐廳候位名單
#
# 排隊有順序，非常適合 List。

# %%
waiting = ['Amy', 'Bob', 'Cindy']
print('下一位：', waiting[0])
print('最後一位：', waiting[-1])

# %% [markdown]
# ## 例題 05｜修改指定位置
#
# List 可以修改原本內容。

# %%
drinks = ['紅茶', '綠茶', '奶茶']
drinks[1] = '烏龍茶'
print(drinks)

# %% [markdown]
# ## 例題 06｜append 加到最後
#
# 購物清單臨時多一項商品。

# %%
shopping = ['牛奶', '麵包']
shopping.append('雞蛋')
print(shopping)

# %% [markdown]
# ## 例題 07｜insert 插入位置
#
# 將最重要的事情放到最前面。

# %%
tasks = ['回覆 Email', '整理報表']
tasks.insert(0, '參加早會')
print(tasks)

# %% [markdown]
# ## 例題 08｜remove 依內容刪除
#
# 知道內容、不知道位置時使用 remove。

# %%
cart = ['鉛筆', '筆記本', '橡皮擦']
cart.remove('鉛筆')
print(cart)

# %% [markdown]
# ## 例題 09｜pop 依位置取出
#
# pop 會刪除並回傳那一筆。

# %%
queue = ['Amy', 'Bob', 'Cindy']
served = queue.pop(0)
print(served)
print(queue)

# %% [markdown]
# ## 例題 10｜in 檢查是否存在
#
# 先檢查再刪除，可以避免錯誤。

# %%
menu = ['紅茶', '綠茶', '奶茶']
if '奶茶' in menu:
    print('今天有奶茶')

# %% [markdown]
# ## 例題 11｜切片取得一部分
#
# 起點包含、終點不包含。

# %%
scores = [60, 70, 80, 90, 100]
print(scores[1:4])
print(scores[:3])
print(scores[-2:])

# %% [markdown]
# ## 例題 12｜排序
#
# sorted 產生新 List；sort 修改原 List。

# %%
scores = [88, 65, 100, 72]
new_scores = sorted(scores)
print(scores)
print(new_scores)

# %% [markdown]
# ## 例題 13｜找最大、最小與總和
#
# Python 內建函式可以快速回答問題。

# %%
scores = [88, 65, 100, 72]
print(max(scores))
print(min(scores))
print(sum(scores))

# %% [markdown]
# ## 例題 14｜List 小作品：旅行清單
#
# 綜合新增、插入、修改與刪除。

# %%
places = ['台南', '高雄']
places.append('花蓮')
places.insert(0, '台北')
places[2] = '屏東'
print(places)

# %% [markdown]
# ## 例題 15｜Tuple：固定資料包
#
# Tuple 有順序，但建立後不能修改。

# %%
gps = (25.0330, 121.5654)
print(gps[0])
print(gps[1])

# %% [markdown]
# ## 例題 16｜Tuple 解包
#
# 一次把固定資料拆到多個變數。

# %%
brand_blue = (20, 80, 160)
red, green, blue = brand_blue
print(red, green, blue)

# %% [markdown]
# ## 例題 17｜List 還是 Tuple
#
# 會改用 List；不希望改用 Tuple。

# %%
shopping = ['牛奶', '麵包']
meeting_point = (25.0330, 121.5654)
shopping.append('雞蛋')
print(shopping, meeting_point)

# %% [markdown]
# ## 例題 18｜小作品：本週任務板
#
# 建立、修改並排序自己的任務。

# %%
tasks = ['完成作業', '複習 List', '整理筆記']
tasks.append('預習 Tuple')
tasks.remove('整理筆記')
print('任務數：', len(tasks))
print(tasks)
