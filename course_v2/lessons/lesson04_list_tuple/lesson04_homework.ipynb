# %% [markdown]
# # lesson04｜課後作業
#
# 每題至少測試三組資料。

# %% [markdown]
# ## 作業 1｜個人待辦清單
#
# 至少完成新增、修改、刪除與排序。

# %%
# 請在這裡完成

# %% [markdown]
# ## 作業 2｜成績分析小幫手
#
# 顯示最高、最低、平均與指定區間。

# %%
# 請在這裡完成

# %% [markdown]
# ## 作業 3｜生活中的固定資料
#
# 自行找一組適合 Tuple 的資料並解釋原因。

# %%
# 請在這裡完成

# %% [markdown]
# ## 作業 4｜候位管理器
#
# 模擬叫號、加入一般客人與 VIP。

# %%
# 請在這裡完成
