# %% [markdown]
# # lesson04｜課堂練習
#
# - ⭐ 必做：全班核心目標
# - ⭐⭐ 應用：完成必做後繼續
# - ⭐⭐⭐ 挑戰：進度較快再做

# %% [markdown]
# ## 練習 01｜⭐ 建立課程清單
#
# 建立三門課，印出第一門、最後一門與數量。

# %%
# 請完成

# %% [markdown]
# ## 練習 02｜⭐ 修改飲料單
#
# 將第二杯飲料改成烏龍茶。

# %%
drinks = ['紅茶', '綠茶', '奶茶']
# 請完成

# %% [markdown]
# ## 練習 03｜⭐ 購物車
#
# 新增雞蛋，再刪除牛奶。

# %%
cart = ['牛奶', '麵包']
# 請完成

# %% [markdown]
# ## 練習 04｜⭐ 候位叫號
#
# 用 pop(0) 取出第一位客人並顯示剩餘名單。

# %%
queue = ['Amy', 'Bob', 'Cindy']
# 請完成

# %% [markdown]
# ## 練習 05｜⭐ 檢查菜單
#
# 若有奶茶印出有販售，否則印出今日售完。

# %%
menu = ['紅茶', '奶茶', '咖啡']
# 使用 in 與 if

# %% [markdown]
# ## 練習 06｜⭐ 固定座標
#
# 建立 Taipei 101 的 Tuple，分別印出經緯度。

# %%
# gps = (...)

# %% [markdown]
# ## 練習 07｜⭐⭐ 成績小幫手
#
# 印出最高、最低、總分與平均。

# %%
scores = [88, 65, 100, 72]
# 平均 = 總分 / 人數

# %% [markdown]
# ## 練習 08｜⭐⭐ 清單切片
#
# 取得前三筆、最後兩筆與中間三筆。

# %%
numbers = [10, 20, 30, 40, 50]
# 請完成

# %% [markdown]
# ## 練習 09｜⭐⭐ 安全刪除
#
# 只有商品存在時才 remove，否則顯示找不到。

# %%
cart = ['筆記本', '鉛筆']
target = '橡皮擦'
# 請完成

# %% [markdown]
# ## 練習 10｜⭐⭐ 行程調整
#
# 完成新增、插隊、修改、刪除各一次。

# %%
places = ['台南', '高雄']
# 自訂旅行清單

# %% [markdown]
# ## 練習 11｜⭐⭐ List 或 Tuple
#
# 分別為可修改的待辦與固定 RGB 選擇容器。

# %%
# 建立 tasks 與 brand_color

# %% [markdown]
# ## 練習 12｜⭐⭐ 電影收藏
#
# 新增兩部、刪除一部，最後排序並印出收藏數。

# %%
movies = ['可可夜總會', '全面啟動']
# 請完成

# %% [markdown]
# ## 練習 13｜⭐⭐⭐ 候位管理器
#
# 叫號一位、新增一位、插入 VIP，最後顯示下一位。

# %%
queue = ['Amy', 'Bob', 'Cindy']
# 請完成

# %% [markdown]
# ## 練習 14｜⭐⭐⭐ 成績修正器
#
# 若分數超過 100 改成 100；低於 0 改成 0。先處理一筆指定位置。

# %%
scores = [88, 105, -3, 72]
index = 1
# 結合 List、Index 與條件判斷

# %% [markdown]
# ## 練習 15｜⭐⭐⭐ 我的任務板
#
# 至少使用 append、insert、remove 或 pop 中三種操作，最後顯示任務數。

# %%
tasks = ['完成作業', '整理筆記']
# 完成自己的版本
