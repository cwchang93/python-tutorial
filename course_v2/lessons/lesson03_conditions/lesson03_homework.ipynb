# %% [markdown]
# # Lesson 03｜課後作業
#
# 每題請加入至少三組測試資料。

# %% [markdown]
# ## 作業 01｜電影分級判斷
#
# 輸入年齡，輸出可觀看的一般級、輔導級或限制級。

# %%
# 請在這裡完成

# %% [markdown]
# ## 作業 02｜BMI 狀態簡化版
#
# 建立 bmi，使用 elif 分成過輕、正常、過重三種結果。

# %%
# 請在這裡完成

# %% [markdown]
# ## 作業 03｜購物折扣計算器
#
# 依消費金額與會員狀態計算不同折扣，清楚顯示原價與應付金額。

# %%
# 請在這裡完成

# %% [markdown]
# ## 作業 04｜自訂生活決策器
#
# 自行選擇通勤、天氣、飲食或工作情境，至少使用 if、elif、else 與一個組合條件。

# %%
# 請在這裡完成
