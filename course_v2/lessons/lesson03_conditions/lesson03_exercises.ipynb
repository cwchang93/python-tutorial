# %% [markdown]
# # Lesson 03｜課堂練習
#
# 先完成運算暖身，再進入條件判斷。題目靈感改寫自 Snakify 條件判斷單元。每題先用中文說規則、預測答案，再執行測試。
#
# ## 第一段｜運算子暖身
#
# 四則運算 → `//`、`%`、`**` → 比較運算 → `if`
#
# ## 第二段｜條件判斷分級
#
# - ⭐ 必做：建立基本信心
# - ⭐⭐ 應用：需要拆解條件
# - ⭐⭐⭐ 挑戰：給進度較快的同學

# %% [markdown]
# ## 暖身 01｜運算暖身：四則運算
#
# 建立 price 與 quantity，計算總價、差額與平均。

# %%
price = 80
quantity = 3
# 請完成 total = price * quantity

# %% [markdown]
# ## 暖身 02｜運算暖身：整除與餘數
#
# 有 23 顆糖果，平均分給 5 人；印出每人幾顆與剩下幾顆。

# %%
candies = 23
people = 5
# 使用 // 與 %

# %% [markdown]
# ## 暖身 03｜運算暖身：次方
#
# 建立 side，計算正方形面積。

# %%
side = 6
# 面積 = side ** 2

# %% [markdown]
# ## 暖身 04｜運算暖身：比較運算
#
# 預測並印出 80 是否大於等於 60、兩個數字是否相等。

# %%
a = 80
b = 60
# 使用 >= 與 ==

# %% [markdown]
# ## 暖身 05｜運算暖身：先算再判斷
#
# 計算購物總額；滿 500 印出符合免運，否則印出還差多少。

# %%
price = 120
quantity = 4
# 先算 total，再使用 if

# %% [markdown]
# ## 暖身 06｜運算暖身：平均分數
#
# 計算三科平均，先印出平均，再印出是否達到 60 分。

# %%
scores = [70, 55, 80]
# 可先直接寫三個變數，不必使用 List

# %% [markdown]
# ## 暖身 07｜運算暖身：邊界值
#
# 測試 score = 59、60、61，觀察 >= 60 與 > 60 的差別。

# %%
score = 60
print(score >= 60)
print(score > 60)

# %% [markdown]
# ## 暖身 08｜運算暖身：型態與運算
#
# 比較 10 + 5 與 "10" + "5" 的結果，說明差異。

# %%
print(10 + 5)
print('10' + '5')

# %% [markdown]
# ## 練習 01｜⭐ 成年判斷
#
# 建立 age，使用 if / else 印出成年或未成年。請測試 17、18、19。

# %%
age = 20
# 請完成條件判斷

# %% [markdown]
# ## 練習 02｜⭐ 及格判斷
#
# 建立 score，60 分以上印出及格，否則印出再加油。請測試 59、60、61。

# %%
score = 72
# 請完成條件判斷

# %% [markdown]
# ## 練習 03｜⭐ 正數、零、負數
#
# 使用 if / elif / else 判斷 number。

# %%
number = -3
# 請完成三種結果

# %% [markdown]
# ## 練習 04｜⭐ 奇偶數
#
# 利用 % 判斷 number 是奇數或偶數。

# %%
number = 17
# 請完成

# %% [markdown]
# ## 練習 05｜⭐ 兩數中的較小值
#
# 比較 a 與 b，印出較小的數；若相同則印出「一樣大」。

# %%
a = 12
b = 7
# 不使用 min()，請用條件判斷

# %% [markdown]
# ## 練習 06｜⭐ 入場資格
#
# 年滿 18 而且有票才可以入場。

# %%
age = 20
has_ticket = True
# 使用 and

# %% [markdown]
# ## 練習 07｜⭐⭐ 成績等級
#
# 90 以上 A、80 以上 B、60 以上 C，其餘待加強。

# %%
score = 85
# 注意條件順序

# %% [markdown]
# ## 練習 08｜⭐⭐ 三數中的最小值
#
# 比較 a、b、c，印出最小值。先不要使用 min()。

# %%
a = 8
b = 3
c = 5
# 想想：a 最小需要同時滿足哪兩個條件？

# %% [markdown]
# ## 練習 09｜⭐⭐ 有幾個數字相等
#
# 三個整數全部相同輸出 3；只有兩個相同輸出 2；都不同輸出 0。

# %%
a = 7
b = 7
c = 3
# 請完成

# %% [markdown]
# ## 練習 10｜⭐⭐ 免運進度
#
# 滿 500 元免運，否則顯示還差多少元。

# %%
amount = 420
# 請完成

# %% [markdown]
# ## 練習 11｜⭐⭐ 閏年判斷
#
# 年份可被 400 整除，或可被 4 整除但不可被 100 整除，就是閏年。

# %%
year = 2024
# 使用 and 與 or

# %% [markdown]
# ## 練習 12｜⭐⭐ 飲料店會員折扣
#
# 會員且滿 150 元打九折，否則原價。

# %%
price = 65
quantity = 3
is_member = True
# 計算 total 與 final_total，最後印出結果

# %% [markdown]
# ## 練習 13｜⭐⭐⭐ 三數排序
#
# 輸入三個互不相同的數字，由小到大印出。可以交換變數內容。

# %%
a = 9
b = 2
c = 6
# 挑戰：完成後再換三組數字測試

# %% [markdown]
# ## 練習 14｜⭐⭐⭐ 巧克力能不能剛好折下來
#
# 一塊 n×m 的巧克力，只沿格線折一次，判斷能否剛好取得 k 格。k 必須小於整塊。

# %%
n = 4
m = 6
k = 8
# 提示：k 是否能被 n 或 m 整除？

# %% [markdown]
# ## 練習 15｜⭐⭐⭐ 自動售票機
#
# 依年齡計算票價：未滿 6 歲免費、6–11 歲 150 元、12–64 歲 300 元、65 歲以上 150 元。

# %%
age = 10
# 請完成四種票價，並測試 5、6、11、12、64、65
