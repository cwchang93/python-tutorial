# %% [markdown]
# # lesson05｜課後作業
#
# 每題至少測試三組資料。

# %% [markdown]
# ## 作業 1｜個人名片 Dict
#
# 保存至少五個欄位，完成新增、修改與安全查詢。

# %%
# 請在這裡完成

# %% [markdown]
# ## 作業 2｜商品庫存管理
#
# 商品有名稱、價格與庫存，依條件更新庫存。

# %%
# 請在這裡完成

# %% [markdown]
# ## 作業 3｜不重複報名名單
#
# 使用 Set 去重，再用 Dict 保存活動摘要。

# %%
# 請在這裡完成

# %% [markdown]
# ## 作業 4｜個人學習儀表板
#
# 整合 Dict、Set、List 與條件判斷。

# %%
# 請在這裡完成
