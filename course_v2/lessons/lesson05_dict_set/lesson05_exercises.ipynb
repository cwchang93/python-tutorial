# %% [markdown]
# # lesson05｜課堂練習
#
# - ⭐ 必做：全班核心目標
# - ⭐⭐ 應用：完成必做後繼續
# - ⭐⭐⭐ 挑戰：進度較快再做

# %% [markdown]
# ## 練習 01｜⭐ 建立學生資料
#
# 建立 name、age、score 三個 Key 並讀取姓名。

# %%
# student = {...}

# %% [markdown]
# ## 練習 02｜⭐ 更新成績
#
# 把 score 從 80 改成 90。

# %%
student = {'name': 'Amy', 'score': 80}
# 請完成

# %% [markdown]
# ## 練習 03｜⭐ 新增城市
#
# 新增 city 欄位。

# %%
student = {'name': 'Amy'}
# 請完成

# %% [markdown]
# ## 練習 04｜⭐ 安全查詢
#
# 用 get 查詢 email，找不到顯示未提供。

# %%
student = {'name': 'Amy'}
# 請完成

# %% [markdown]
# ## 練習 05｜⭐ 商品庫存
#
# 賣出一件後庫存減 1；有庫存才處理。

# %%
product = {'name': '筆記本', 'stock': 3}
# 結合 if

# %% [markdown]
# ## 練習 06｜⭐ Email 去重
#
# 把重複 Email 轉為 Set，顯示不重複人數。

# %%
emails = ['a@test.com', 'b@test.com', 'a@test.com']
# 請完成

# %% [markdown]
# ## 練習 07｜⭐⭐ 聯絡人卡片
#
# 新增、修改、查詢各一個欄位。

# %%
contact = {'name': '媽媽', 'phone': '0912-345-678'}
# 請完成

# %% [markdown]
# ## 練習 08｜⭐⭐ 安全刪除欄位
#
# 如果 coupon 存在就 pop，否則顯示沒有優惠券。

# %%
order = {'id': 1001, 'total': 680}
# 請完成

# %% [markdown]
# ## 練習 09｜⭐⭐ 技能集合
#
# 新增 SQL、移除 Word，顯示技能數。

# %%
skills = {'Python', 'Excel'}
# 使用 add、discard

# %% [markdown]
# ## 練習 10｜⭐⭐ 共同技能
#
# 找出兩組共同技能與全部技能。

# %%
a = {'Python', 'Excel'}
b = {'Python', 'SQL'}
# 使用 & 與 |

# %% [markdown]
# ## 練習 11｜⭐⭐ 會員折扣
#
# Dict 保存會員資料，會員且消費滿 500 打九折。

# %%
member = {'name': 'Amy', 'is_member': True}
amount = 600
# 請完成

# %% [markdown]
# ## 練習 12｜⭐⭐ 多位學生
#
# 取得 Bob 的成績並判斷是否及格。

# %%
students = [{'name': 'Amy', 'score': 95}, {'name': 'Bob', 'score': 58}]
# 請完成

# %% [markdown]
# ## 練習 13｜⭐⭐⭐ 商品小卡
#
# 建立商品 Dict、更新庫存、加入分類，最後格式化輸出。

# %%
product = {'name': 'Notebook', 'price': 120, 'stock': 8}
# 請完成

# %% [markdown]
# ## 練習 14｜⭐⭐⭐ 報名整理器
#
# 用 Set 去除重複報名，再用 Dict 保存活動名稱與人數。

# %%
emails = ['amy@test.com', 'bob@test.com', 'amy@test.com']
# 請完成 event

# %% [markdown]
# ## 練習 15｜⭐⭐⭐ 個人學習儀表板
#
# 至少使用一個 Dict、一個 Set、一個 List 與一個 if。

# %%
# 完成自己的版本

# %% [markdown]
# ## 練習 16｜⭐⭐ 商品資料更新
#
# 使用 `update()` 同時更新價格與庫存，再用 `items()` 印出資料。

# %%
product = {'name': '保溫杯', 'price': 480, 'stock': 10}
# 請完成

# %% [markdown]
# ## 練習 17｜⭐⭐ 課程名單比較
#
# 找出 Python 與 SQL 課程的共同學員，以及只上 Python 的學員。

# %%
python_class = {'Amy', 'Bob', 'Cindy'}
sql_class = {'Bob', 'Cindy', 'David'}
# 請完成

# %% [markdown]
# ## 練習 18｜⭐⭐ 讀取會員卡
# 使用 `items()` 印出會員資料。

# %%
member = {'name':'Amy', 'level':'gold', 'points':320}
# 請完成

# %% [markdown]
# ## 練習 19｜⭐⭐ 更新商品
# 使用 `update()` 同時更新價格與庫存。

# %%
product = {'name':'保溫杯', 'price':480, 'stock':10}
# 請完成

# %% [markdown]
# ## 練習 20｜⭐⭐ 取出欄位
# 用 `pop()` 取出會員的電話並印出剩餘資料。

# %%
contact = {'name':'Amy', 'phone':'0912-345-678', 'city':'Taipei'}
# 請完成

# %% [markdown]
# ## 練習 21｜⭐⭐ 課程聯集
# 找出兩堂課的所有不重複學員。

# %%
python_class = {'Amy','Bob'}
sql_class = {'Bob','Cindy'}
# 請完成

# %% [markdown]
# ## 練習 22｜⭐⭐ 共同技能
# 找出兩位同學共同擁有的技能。

# %%
amy = {'Python','Excel','SQL'}
bob = {'Python','Power BI'}
# 請完成

# %% [markdown]
# ## 練習 23｜⭐⭐ 商品安全查詢
# 用 `get()` 查詢不存在的折扣欄位，預設顯示 0。

# %%
product = {'name':'筆記本', 'price':120}
# 請完成

# %% [markdown]
# ## 練習 24｜⭐⭐⭐ 多筆資料欄位
# 從 List 裡的 Dict 印出所有商品名稱。

# %%
products = [{'name':'筆記本','price':120},{'name':'鉛筆','price':20}]
# 請完成

# %% [markdown]
# ## 練習 25｜⭐⭐⭐ 學習標籤整理
# 建立 Dict 個人資料與 Set 技能，若技能數至少 3 個就顯示準備充分。

# %%
profile = {'name':'Amy'}
skills = {'Python','List','Dict'}
# 請完成
