# %% [markdown]
# # Lesson 16｜回家作業：訂單資料清潔隊

# %% [markdown]
# 使用 `lesson16_orders_dirty.csv`：
#
# 1. 保留 raw_df。
# 2. 統一欄名與文字格式。
# 3. 轉換數字與日期。
# 4. 處理缺值與重複。
# 5. 再次檢查缺值、重複與型態。
# 6. 另存 `lesson16_homework_cleaned.csv`，不可覆蓋原始檔。

# %%
from pathlib import Path
import pandas as pd

possible_paths = [
    Path("course_v2/data/lesson16_orders_dirty.csv"),
    Path("data/lesson16_orders_dirty.csv"),
    Path("../../data/lesson16_orders_dirty.csv"),
    Path("lesson16_orders_dirty.csv"),
]
data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break
if not data_path.exists():
    raise FileNotFoundError("找不到 lesson16_orders_dirty.csv")
df = pd.read_csv(data_path)

raw_df = df.copy()
clean_df = df.copy()

# 請開始清理
