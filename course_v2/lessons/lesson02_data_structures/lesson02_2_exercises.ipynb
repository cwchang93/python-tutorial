# %% [markdown]
# # Lesson 02-2｜課堂練習

# %% [markdown]
# ## 暖身｜課程 List
#
# 建立三門課，取得第一門、最後一門與總數。

# %%
# TODO

# %% [markdown]
# ## Core 1｜購物車
#
# 從 `['Book', 'Pen']` 開始：加入 Notebook、把 Pen 改成 Pencil、刪除 Book。

# %%
cart = ['Book', 'Pen']
# TODO

# %% [markdown]
# ## Core 2｜學生資料
#
# 建立 name、age、score；修改 score，並加入 city。

# %%
# TODO

# %% [markdown]
# ## Practice｜Email 去重
#
# 去除重複 Email、加入新 Email，印出不重複數量。

# %%
emails = ['a@example.com', 'b@example.com', 'a@example.com']
# TODO

# %% [markdown]
# ## Practice 2｜電影收藏
#
# 用 List 保存三部電影；加入、修改、刪除各一次，再印出收藏數量。

# %%
# TODO

# %% [markdown]
# ## Challenge｜我的學習儀表板
#
# 用 List 保存本週任務、Dict 保存個人學習資料、Set 保存已學會且不重複的技能，最後輸出摘要。

# %%
# TODO：內容可以完全自訂
