# %% [markdown]
# # Lesson 02-2｜課後作業

# %% [markdown]
# ## 作業 1｜個人技能清單
#
# 完成新增、修改、刪除各一次。

# %%
# TODO

# %% [markdown]
# ## 作業 2｜商品資料
#
# 用 Dict 保存名稱、價格與庫存；修改庫存並新增分類。

# %%
# TODO

# %% [markdown]
# ## 作業 3｜生活資料整理器
#
# 自行選擇至少兩種資料結構，整理一個生活或工作情境。

# %%
# TODO
