# %% [markdown]
# # Lesson 02-1｜課後作業
#
# 用自己的生活資料練習，重點是能說明為什麼選擇該型態。

# %% [markdown]
# ## 作業 1｜生活資料分類
#
# 從自己的生活列出兩個 int、兩個 float、兩個 str、兩個 bool，並用 type() 驗證。

# %%
# 在這裡完成你的程式

# %% [markdown]
# ## 作業 2｜個人資料小卡
#
# 建立姓名、年齡、身高、電話、是否為學生，輸出一張清楚的小卡。

# %%
# 在這裡完成你的程式

# %% [markdown]
# ## 作業 3｜修正四種錯誤
#
# 各設計並修正一個大小寫、引號、縮排、型態轉換錯誤。

# %%
# 在這裡完成你的程式

# %% [markdown]
# ## 作業 4｜自己的生活計算器
#
# 選擇購物、交通、旅行或工作情境，至少使用 int、float、str、bool 各一個。

# %%
# 在這裡完成你的程式
