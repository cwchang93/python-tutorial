# %% [markdown]
# # Lesson 02-1｜課堂練習
#
# 共 10 題，依序練習縮排、四種基本型態、比較與型態轉換。

# %% [markdown]
# ## 暖身｜修正縮排
#
# 修正程式，讓 `及格` 可以正確印出。

# %%
score = 80

# 請修正下一行的縮排
# if score >= 60:
# print('及格')

# %% [markdown]
# ## Core 1｜挑選正確型態
#
# 為年齡、身高、電話與是否付款建立變數，再用 `type()` 檢查。

# %%
# age =
# height =
# phone =
# is_paid =

# print(type(age), type(height), type(phone), type(is_paid))

# %% [markdown]
# ## Core 2｜int 生活計算
#
# 班上 24 人、請假 3 人，計算出席人數。

# %%
# students = 24
# absent = 3
# attendance =
# print('出席：', attendance)

# %% [markdown]
# ## Core 3｜float 折扣
#
# 商品 500 元、打 8 折，計算折扣後價格。

# %%
# price = 500
# discount = 0.8
# final_price =
# print('折扣後：', final_price)

# %% [markdown]
# ## Core 4｜str 識別資料
#
# 建立電話 `'0912-345-678'` 與學號 `'00123'`，說明為何不能用 int。

# %%
# phone =
# student_id =
# print(phone, student_id)
# print(type(phone), type(student_id))

# %% [markdown]
# ## Core 5｜字串操作
#
# 使用姓名完成串接，並印出名字長度。

# %%
first_name = 'Amy'
last_name = 'Chen'

# full_name =
# print(full_name)
# print(len(full_name))

# %% [markdown]
# ## Core 6｜bool 與比較
#
# 使用年齡 20，印出是否成年、是否剛好 20 歲。

# %%
age = 20

# is_adult =
# is_twenty =
# print(is_adult, is_twenty)

# %% [markdown]
# ## Practice 1｜型態偵探
#
# 先預測四個結果，再執行確認。

# %%
print(type(10))
print(type(10.0))
print(type('10'))
print(type(True))

# %% [markdown]
# ## Practice 2｜型態轉換
#
# 把 `'250'`、`'3'` 轉成數字後相乘，再把結果放進一句文字。

# %%
text_price = '250'
text_quantity = '3'

# total =
# message =
# print(message)

# %% [markdown]
# ## Challenge｜活動報名確認單
#
# 建立活動名稱、票價、張數、付款狀態，輸出總價與所有資料型態。

# %%
# event =
# ticket_price =
# quantity =
# is_paid =
# total =

# print('活動：', event)
# print('總價：', total)
# print('已付款：', is_paid)
