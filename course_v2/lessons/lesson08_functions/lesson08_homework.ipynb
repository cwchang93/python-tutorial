# %% [markdown]
# # Lesson 08｜課後作業
#
# 每個功能至少拆成兩個函式，並測試三組資料。

# %% [markdown]
# ## 作業 1｜BMI 工具
#
# 建立 BMI 計算與分類函式。

# %%
# 請在這裡完成

# %% [markdown]
# ## 作業 2｜購物車工具組
#
# 建立小計、折扣、運費與總額函式。

# %%
# 請在這裡完成

# %% [markdown]
# ## 作業 3｜成績報表
#
# 建立平均、最高分、及格人數與摘要函式。

# %%
# 請在這裡完成

# %% [markdown]
# ## 作業 4｜Lesson 07 重構
#
# 把登入或 ATM 程式拆成可重複使用的函式。

# %%
# 請在這裡完成
