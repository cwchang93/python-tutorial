# %% [markdown]
# # Lesson 09｜錯誤處理
#
# 先讀懂錯誤，再用 try、except、else、finally 保護程式。

# %% [markdown]
# ## 例題 01｜錯誤處理報表

# %%
# 讀取一批成績字串，輸出有效資料、錯誤筆數與平均。

# %% [markdown]
# ## 例題 02｜安全購物車

# %%
# 處理商品價格與數量輸入，錯誤資料要有清楚提示。

# %% [markdown]
# ## 例題 03｜檔案防呆

# %%
# 開啟檔案並處理不存在、編碼或內容格式問題。

# %% [markdown]
# ## 例題 04｜綜合驗證函式

# %%
# 寫一個函式完成轉換、範圍驗證與錯誤回傳。
