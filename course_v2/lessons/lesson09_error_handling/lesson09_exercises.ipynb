# %% [markdown]
# # Lesson 09｜錯誤處理
#
# 先讀懂錯誤，再用 try、except、else、finally 保護程式。

# %% [markdown]
# ## 例題 01｜安全轉換年齡

# %%
# 把字串轉成整數；失敗時輸出『年齡格式錯誤』。

# %% [markdown]
# ## 例題 02｜安全計算平均

# %%
# 當人數為 0 時不要除法，輸出『沒有資料』。

# %% [markdown]
# ## 例題 03｜清單索引防呆

# %%
# 讓使用者輸入索引，捕捉 ValueError 與 IndexError。

# %% [markdown]
# ## 例題 04｜字典查詢防呆

# %%
# 查詢會員 email，找不到時輸出『查無會員』。

# %% [markdown]
# ## 例題 05｜分數範圍驗證

# %%
# 分數非 0～100 或不是整數時都視為錯誤。

# %% [markdown]
# ## 例題 06｜輸入折扣

# %%
# 把折扣轉成 float，失敗時使用 0。

# %% [markdown]
# ## 例題 07｜try else

# %%
# 成功讀取商品數量才計算小計，失敗時顯示提示。

# %% [markdown]
# ## 例題 08｜finally 提示

# %%
# 模擬開始與結束工作，無論結果都印出『流程結束』。

# %% [markdown]
# ## 例題 09｜負數數量

# %%
# 用 raise ValueError 阻止負數數量。

# %% [markdown]
# ## 例題 10｜捕捉自訂錯誤

# %%
# 呼叫上題函式並捕捉 ValueError。

# %% [markdown]
# ## 例題 11｜多筆分數

# %%
# 從字串清單轉成整數，略過無法轉換的項目。

# %% [markdown]
# ## 例題 12｜錯誤統計

# %%
# 統計一批輸入中成功與失敗的筆數。

# %% [markdown]
# ## 例題 13｜訂單編號

# %%
# 字典查詢訂單，不存在時輸出清楚訊息。

# %% [markdown]
# ## 例題 14｜檔案不存在

# %%
# 開啟不存在的文字檔並捕捉 FileNotFoundError。

# %% [markdown]
# ## 例題 15｜多種例外

# %%
# 同時處理 ValueError 與 ZeroDivisionError。

# %% [markdown]
# ## 例題 16｜安全平均函式

# %%
# 寫一個函式，空清單回傳 None，否則回傳平均。

# %% [markdown]
# ## 例題 17｜安全價格函式

# %%
# 價格不能為負，錯誤時回傳 None。

# %% [markdown]
# ## 例題 18｜錯誤訊息紀錄

# %%
# 把每筆錯誤文字收集到 errors 清單。

# %% [markdown]
# ## 例題 19｜輸入三次

# %%
# 處理三筆年齡資料並列出無效輸入。

# %% [markdown]
# ## 例題 20｜購物車小計

# %%
# 數量或價格錯誤時不讓程式中斷。

# %% [markdown]
# ## 例題 21｜成績報表

# %%
# 轉換成績並輸出最高分、最低分與錯誤筆數。

# %% [markdown]
# ## 例題 22｜安全除法

# %%
# 寫 safe_divide(a, b)，b 為 0 回傳 None。

# %% [markdown]
# ## 例題 23｜錯誤分類

# %%
# 將輸入錯誤分類為格式錯誤或範圍錯誤。

# %% [markdown]
# ## 例題 24｜資料驗證流程

# %%
# 先轉換、再驗證範圍，成功才加入清單。

# %% [markdown]
# ## 例題 25｜綜合訂單檢查

# %%
# 處理商品、數量與價格，輸出有效訂單總額。
