# %% [markdown]
# # Lesson 01｜課堂練習
#
# 依序完成暖身、核心與應用；有餘力再挑戰小作品。

# %% [markdown]
# ## 暖身 1｜成功訊息
#
# 印出：`我準備好學 Python 了！`

# %%
# TODO

# %% [markdown]
# ## 暖身 2｜文字還是算式？
#
# 分別印出文字 `50 + 30`，以及真正的計算結果。

# %%
# TODO

# %% [markdown]
# ## Core 1｜三個個人變數
#
# 建立 `name`、`job`、`goal`，分三行顯示。

# %%
# TODO

# %% [markdown]
# ## Core 2｜午餐計算器
#
# 餐點 120 元、飲料 45 元，購買 2 份餐點與 1 杯飲料。計算總金額。

# %%
# TODO：建立 meal_price、drink_price、meal_quantity、total

# %% [markdown]
# ## Practice｜一週學習計畫
#
# 每天 35 分鐘、每週 5 天，計算一週總分鐘與四週總分鐘。

# %%
# TODO

# %% [markdown]
# ## Challenge｜我的第一張數位名片
#
# 使用至少四個變數，輸出有標題、姓名、職業、興趣與學習目標的數位名片。

# %%
# TODO：內容可以完全自訂
