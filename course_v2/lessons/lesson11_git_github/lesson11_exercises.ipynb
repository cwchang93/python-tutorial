# %% [markdown]
# # Lesson 11｜課堂練習
#
# 先獨立完成，再逐題檢討。每題都延續 learning 的同一條學習主線。

# %% [markdown]
# ## 題目 01｜確認 Git 是否安裝
#
# 執行指令並觀察 Git 版本。

# %%
# 執行指令並觀察 Git 版本。
# 請在這裡完成

# %% [markdown]
# ## 題目 02｜查看目前資料夾
#
# 確認 Notebook 目前所在位置。

# %%
# 確認 Notebook 目前所在位置。
# 請在這裡完成

# %% [markdown]
# ## 題目 03｜建立專案資料夾
#
# 建立 practice_git_project 資料夾。

# %%
# 建立 practice_git_project 資料夾。
# 請在這裡完成

# %% [markdown]
# ## 題目 04｜Git 初始化
#
# 把資料夾變成 Git Repository。

# %%
# 把資料夾變成 Git Repository。
# 請在這裡完成

# %% [markdown]
# ## 題目 05｜查看狀態
#
# 使用 status 查看目前版本狀態。

# %%
# 使用 status 查看目前版本狀態。
# 請在這裡完成

# %% [markdown]
# ## 題目 06｜建立第一個程式
#
# 建立 hello.py，作為第一個版本。

# %%
# 建立 hello.py，作為第一個版本。
# 請在這裡完成

# %% [markdown]
# ## 題目 07｜辨識未追蹤檔案
#
# 再次查看狀態，找出 ?? 的意義。

# %%
# 再次查看狀態，找出 ?? 的意義。
# 請在這裡完成

# %% [markdown]
# ## 題目 08｜加入暫存區
#
# 使用 git add 選擇要放進下一個版本的檔案。

# %%
# 使用 git add 選擇要放進下一個版本的檔案。
# 請在這裡完成

# %% [markdown]
# ## 題目 09｜建立 Commit
#
# 為目前版本建立清楚的訊息。

# %%
# 為目前版本建立清楚的訊息。
# 請在這裡完成

# %% [markdown]
# ## 題目 10｜查看版本紀錄
#
# 用精簡格式查看 Commit。

# %%
# 用精簡格式查看 Commit。
# 請在這裡完成

# %% [markdown]
# ## 題目 11｜修改程式
#
# 替 hello.py 加入第二行內容。

# %%
# 替 hello.py 加入第二行內容。
# 請在這裡完成

# %% [markdown]
# ## 題目 12｜查看差異
#
# 用 diff 比較工作區與上次 Commit。

# %%
# 用 diff 比較工作區與上次 Commit。
# 請在這裡完成

# %% [markdown]
# ## 題目 13｜提交第二版
#
# 把修改加入暫存區並建立第二個 Commit。

# %%
# 把修改加入暫存區並建立第二個 Commit。
# 請在這裡完成

# %% [markdown]
# ## 題目 14｜建立 README
#
# 寫下專案用途與執行方式。

# %%
# 寫下專案用途與執行方式。
# 請在這裡完成

# %% [markdown]
# ## 題目 15｜忽略暫存檔
#
# 建立 .gitignore，避免提交 cache 與暫存檔。

# %%
# 建立 .gitignore，避免提交 cache 與暫存檔。
# 請在這裡完成

# %% [markdown]
# ## 題目 16｜一次檢查所有狀態
#
# 確認 README 與 .gitignore 尚未提交。

# %%
# 確認 README 與 .gitignore 尚未提交。
# 請在這裡完成

# %% [markdown]
# ## 題目 17｜提交文件
#
# 將 README 與 .gitignore 放入同一個文件 Commit。

# %%
# 將 README 與 .gitignore 放入同一個文件 Commit。
# 請在這裡完成

# %% [markdown]
# ## 題目 18｜理解 GitHub Remote
#
# 列出目前遠端；尚未設定時不會顯示內容。

# %%
# 列出目前遠端；尚未設定時不會顯示內容。
# 請在這裡完成

# %% [markdown]
# ## 題目 19｜設定遠端示範
#
# 請把網址換成自己的 GitHub Repository；本格只示範指令，不直接執行。

# %%
# 請把網址換成自己的 GitHub Repository；本格只示範指令，不直接執行。
# 請在這裡完成

# %% [markdown]
# ## 題目 20｜Push 指令示範
#
# 第一次 Push 通常要指定 origin 與 main。

# %%
# 第一次 Push 通常要指定 origin 與 main。
# 請在這裡完成

# %% [markdown]
# ## 題目 21｜Clone 指令示範
#
# Clone 是把遠端 Repository 完整複製到本機。

# %%
# Clone 是把遠端 Repository 完整複製到本機。
# 請在這裡完成

# %% [markdown]
# ## 題目 22｜Pull 指令示範
#
# Pull 是把遠端的新版本同步回目前資料夾。

# %%
# Pull 是把遠端的新版本同步回目前資料夾。
# 請在這裡完成

# %% [markdown]
# ## 題目 23｜比較 Push、Pull、Clone
#
# 用 Dict 整理三個指令的用途。

# %%
# 用 Dict 整理三個指令的用途。
# 請在這裡完成

# %% [markdown]
# ## 題目 24｜安全操作檢查表
#
# 輸出操作前的三項檢查。

# %%
# 輸出操作前的三項檢查。
# 請在這裡完成

# %% [markdown]
# ## 題目 25｜完成版本歷史
#
# 查看完整練習專案的精簡版本紀錄。

# %%
# 查看完整練習專案的精簡版本紀錄。
# 請在這裡完成
