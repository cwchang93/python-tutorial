# %% [markdown]
# # Lesson 06｜課後作業
#
# 每題至少測試三組資料。

# %% [markdown]
# ## 作業 1｜每日支出統計
#
# 用 for 計算支出總和、平均與超過 500 元的筆數。

# %%
# 請在這裡完成

# %% [markdown]
# ## 作業 2｜成績報表
#
# 逐筆印出學生姓名、分數與及格狀態。

# %%
# 請在這裡完成

# %% [markdown]
# ## 作業 3｜庫存警示器
#
# 找出庫存低於門檻的商品。

# %%
# 請在這裡完成

# %% [markdown]
# ## 作業 4｜銷售統計器
#
# 完成總營收、高價訂單與平均訂單金額。

# %%
# 請在這裡完成
