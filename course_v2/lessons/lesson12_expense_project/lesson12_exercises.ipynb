# %% [markdown]
# # Lesson 12｜課堂練習
#
# 先獨立完成，再逐題檢討。每題都延續 learning 的同一條學習主線。

# %% [markdown]
# ## 題目 01｜建立交易資料
#
# 先用 List 與 Dict 表示三筆收入／支出。

# %%
# 先用 List 與 Dict 表示三筆收入／支出。
# 請在這裡完成

# %% [markdown]
# ## 題目 02｜逐筆顯示
#
# 使用 for 迴圈印出日期、分類與金額。

# %%
# 使用 for 迴圈印出日期、分類與金額。
# 請在這裡完成

# %% [markdown]
# ## 題目 03｜計算總餘額
#
# 使用迴圈計算所有金額。

# %%
# 使用迴圈計算所有金額。
# 請在這裡完成

# %% [markdown]
# ## 題目 04｜分開收入與支出
#
# 以條件判斷分別加總正數與負數。

# %%
# 以條件判斷分別加總正數與負數。
# 請在這裡完成

# %% [markdown]
# ## 題目 05｜新增交易函式
#
# 用函式集中建立資料的規則。

# %%
# 用函式集中建立資料的規則。
# 請在這裡完成

# %% [markdown]
# ## 題目 06｜驗證空白分類
#
# 分類不可為空白，否則主動 raise。

# %%
# 分類不可為空白，否則主動 raise。
# 請在這裡完成

# %% [markdown]
# ## 題目 07｜轉換金額
#
# 將文字金額安全轉成 float。

# %%
# 將文字金額安全轉成 float。
# 請在這裡完成

# %% [markdown]
# ## 題目 08｜顯示單筆交易
#
# 用函式建立一致的輸出格式。

# %%
# 用函式建立一致的輸出格式。
# 請在這裡完成

# %% [markdown]
# ## 題目 09｜顯示全部交易
#
# 重複使用 format_record。

# %%
# 重複使用 format_record。
# 請在這裡完成

# %% [markdown]
# ## 題目 10｜分類支出統計
#
# 使用 Dict 累加各分類支出。

# %%
# 使用 Dict 累加各分類支出。
# 請在這裡完成

# %% [markdown]
# ## 題目 11｜找出最大支出
#
# 只比較支出資料，輸出金額最高的一筆。

# %%
# 只比較支出資料，輸出金額最高的一筆。
# 請在這裡完成

# %% [markdown]
# ## 題目 12｜依日期篩選
#
# 寫函式找出指定日期的交易。

# %%
# 寫函式找出指定日期的交易。
# 請在這裡完成

# %% [markdown]
# ## 題目 13｜依分類篩選
#
# 不分前後空白搜尋指定分類。

# %%
# 不分前後空白搜尋指定分類。
# 請在這裡完成

# %% [markdown]
# ## 題目 14｜準備 CSV 路徑
#
# 建立 data 資料夾與檔案路徑。

# %%
# 建立 data 資料夾與檔案路徑。
# 請在這裡完成

# %% [markdown]
# ## 題目 15｜寫入 CSV
#
# 使用 DictWriter 保存交易。

# %%
# 使用 DictWriter 保存交易。
# 請在這裡完成

# %% [markdown]
# ## 題目 16｜讀取 CSV
#
# 讀取後把 amount 轉回 float。

# %%
# 讀取後把 amount 轉回 float。
# 請在這裡完成

# %% [markdown]
# ## 題目 17｜保存函式
#
# 把 CSV 寫入步驟整理成可重複使用的函式。

# %%
# 把 CSV 寫入步驟整理成可重複使用的函式。
# 請在這裡完成

# %% [markdown]
# ## 題目 18｜摘要函式
#
# 回傳收入、支出與餘額。

# %%
# 回傳收入、支出與餘額。
# 請在這裡完成

# %% [markdown]
# ## 題目 19｜刪除交易
#
# 使用編號刪除前先驗證範圍。

# %%
# 使用編號刪除前先驗證範圍。
# 請在這裡完成

# %% [markdown]
# ## 題目 20｜選單畫面
#
# 建立清楚的文字選單。

# %%
# 建立清楚的文字選單。
# 請在這裡完成

# %% [markdown]
# ## 題目 21｜處理選單選擇
#
# 用 Dict 對照選項與功能名稱。

# %%
# 用 Dict 對照選項與功能名稱。
# 請在這裡完成

# %% [markdown]
# ## 題目 22｜輸入日期驗證
#
# 使用 datetime 檢查 YYYY-MM-DD。

# %%
# 使用 datetime 檢查 YYYY-MM-DD。
# 請在這裡完成

# %% [markdown]
# ## 題目 23｜產生文字報表
#
# 把摘要整理成容易閱讀的文字。

# %%
# 把摘要整理成容易閱讀的文字。
# 請在這裡完成

# %% [markdown]
# ## 題目 24｜輸出報表檔案
#
# 把摘要保存成 summary.txt。

# %%
# 把摘要保存成 summary.txt。
# 請在這裡完成

# %% [markdown]
# ## 題目 25｜整合專案流程
#
# 載入資料、加入一筆、保存並顯示摘要。

# %%
# 載入資料、加入一筆、保存並顯示摘要。
# 請在這裡完成
