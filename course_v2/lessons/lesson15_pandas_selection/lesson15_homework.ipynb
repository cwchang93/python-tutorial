# %% [markdown]
# # Lesson 15｜回家作業：找出值得關注的訂單

# %% [markdown]
# 使用 `lesson13_orders.csv`：
#
# 1. 新增 revenue 欄位。
# 2. 篩選台北、新北或桃園且 revenue >= 150 的訂單。
# 3. 只保留 order_id、product、city、revenue。
# 4. 依 revenue 由大到小排序並顯示前 8 筆。
# 5. 用一句話說明查詢結果。

# %%
from pathlib import Path
import pandas as pd

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]
data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break
if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv")
df = pd.read_csv(data_path)

# 請從新增欄位開始完成
