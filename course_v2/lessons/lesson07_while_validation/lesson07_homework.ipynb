# %% [markdown]
# # Lesson 07｜課後作業
#
# 每題至少測試三種輸入，包括錯誤資料。

# %% [markdown]
# ## 作業 1｜安全會員登入
#
# 完成帳號、密碼與三次重試。

# %%
# 請在這裡完成

# %% [markdown]
# ## 作業 2｜電影票購買
#
# 驗證張數、票種並計算總價。

# %%
# 請在這裡完成

# %% [markdown]
# ## 作業 3｜簡易 ATM
#
# 完成查詢、存款、提款與離開。

# %%
# 請在這裡完成

# %% [markdown]
# ## 作業 4｜資料輸入器
#
# 持續輸入分數，輸入 end 後顯示總數、最高分與平均。

# %%
# 請在這裡完成
