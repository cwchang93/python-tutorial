# %% [markdown]
# # Lesson 17-18 Review：Python x Data Analysis 題目整理
#
# 這份練習依照 `summary.md` 的重點設計，題目只保留基礎到中階。
#
# 設計原則：
# - 以生活化、實用、資料分析導向為主。
# - 前半段練 Python 基礎語法與資料處理觀念。
# - 後半段練真實分析流程：讀資料、清資料、統計、畫圖。
# - 請先自己完成，再另外做解答版。

# %% [markdown]
# ## 使用方式
#
# 1. 先讀每一題的情境。
# 2. 在下方 code cell 完成 `TODO`。
# 3. 儘量讓輸出清楚，像是在寫小型分析報告。
# 4. 後面的 pandas / matplotlib / numpy 題組，可以分多格完成。

# %% [markdown]
# ---
#
# ## Lesson 02｜基礎語法、變數、型別
#
# ### 題目 1：早餐店營收計算
#
# 你今天賣了 3 杯紅茶，每杯 25 元；2 份蛋餅，每份 35 元。
#
# 請完成：
# 1. 建立變數 `tea_qty`, `tea_price`, `roll_qty`, `roll_price`
# 2. 計算總營收 `total_revenue`
# 3. 印出格式：`今日總營收 = xxx`

# %%
# TODO

# %% [markdown]
# ### 題目 2：把字串數字轉成可計算的資料
#
# 某平台傳來的訂單數量和單價如下：
# - `qty = "12"`
# - `unit_price = "79.5"`
#
# 請完成：
# 1. 將它們轉成正確型別
# 2. 計算訂單金額
# 3. 印出每個變數的型別

# %%
qty = "12"
unit_price = "79.5"

# TODO

# %% [markdown]
# ### 題目 3：比較方案哪個比較便宜
#
# 影音平台有兩種方案：
# - 月費方案：每月 199 元
# - 季費方案：3 個月 540 元
#
# 請完成：
# 1. 算出季費平均每月多少錢
# 2. 比較哪個方案比較便宜
# 3. 印出比較結果

# %%
# TODO

# %% [markdown]
# ---
#
# ## Lesson 03｜字串、串列、條件判斷
#
# ### 題目 1：清理會員姓名字串
#
# 收到一筆使用者資料：
# `raw_name = "   aMy chen   "`
#
# 請完成：
# 1. 去掉前後空白
# 2. 全部轉成小寫
# 3. 將姓名整理成比較一致的格式後印出
#
# 提示：可先用 `strip()`、`lower()`。

# %%
raw_name = "   aMy chen   "

# TODO

# %% [markdown]
# ### 題目 2：拆開一行 CSV 文字
#
# 有一行手動匯出的資料：
# `row = "2025-03-01,coffee,3,150"`
#
# 欄位依序是：日期、商品、數量、金額。
#
# 請完成：
# 1. 用 `split()` 拆開資料
# 2. 分別存到對應變數
# 3. 印出一段句子，例如：`2025-03-01 coffee 賣出 3 筆，金額 150`

# %%
row = "2025-03-01,coffee,3,150"

# TODO

# %% [markdown]
# ### 題目 3：判斷訂單等級
#
# 給定訂單金額 `amount`：
# - 1000 以上：`VIP`
# - 500 到 999：`Normal`
# - 低於 500：`Small`
#
# 請用 `if-elif-else` 完成。

# %%
amount = 780

# TODO

# %% [markdown]
# ---
#
# ## Lesson 04｜for / while 迴圈
#
# ### 題目 1：計算一週總營收
#
# 一週營收如下：
# `revenues = [1200, 980, 1350, 1500, 1100, 1680, 1420]`
#
# 請使用 `for` 迴圈計算總營收與平均營收。

# %%
revenues = [1200, 980, 1350, 1500, 1100, 1680, 1420]

# TODO

# %% [markdown]
# ### 題目 2：數高單價訂單有幾筆
#
# 訂單金額如下：
# `orders = [120, 560, 80, 999, 430, 1250, 300]`
#
# 請用 `for` 迴圈計算金額大於等於 500 的訂單有幾筆。

# %%
orders = [120, 560, 80, 999, 430, 1250, 300]

# TODO

# %% [markdown]
# ### 題目 3：找第一個缺貨商品
#
# 庫存清單如下：
# `stocks = [12, 8, 5, 0, 7, 3]`
#
# 請用 `while` 迴圈找出第一個庫存為 0 的索引位置，找到就停止。
#
# 提示：可搭配 `break`。

# %%
stocks = [12, 8, 5, 0, 7, 3]

# TODO

# %% [markdown]
# ---
#
# ## Lesson 05｜函式、return、錯誤觀念
#
# ### 題目 1：寫一個平均訂單金額函式
#
# 請撰寫函式 `calc_avg_order(amounts)`：
# - 參數是一個金額串列
# - 回傳平均值
# - 然後測試它

# %%
# TODO

# %% [markdown]
# ### 題目 2：寫一個判斷高價訂單函式
#
# 請撰寫函式 `is_large_order(amount)`：
# - 如果金額 >= 1000，回傳 `True`
# - 否則回傳 `False`
#
# 再用幾個不同金額測試它。

# %%
# TODO

# %% [markdown]
# ### 題目 3：安全轉換輸入資料
#
# 請撰寫函式 `safe_to_int(text)`：
# - 如果可以轉成整數，就回傳整數
# - 如果不行，就回傳 `None`
#
# 請測試：`"120"`、`"abc"`、`"50"`

# %%
# TODO

# %% [markdown]
# ---
#
# ## Lesson 06｜排序、字典、例外處理
#
# ### 題目 1：找出前三高消費金額
#
# 給定：
# `spending = [520, 1200, 300, 860, 1500, 430, 990]`
#
# 請完成：
# 1. 由大到小排序
# 2. 取出前三高
# 3. 印出結果

# %%
spending = [520, 1200, 300, 860, 1500, 430, 990]

# TODO

# %% [markdown]
# ### 題目 2：統計訂單通路次數
#
# 給定通路資料：
# `channels = ["web", "app", "web", "store", "app", "web"]`
#
# 請用字典統計每個通路出現幾次。
#
# 提示：可搭配 `get()`。

# %%
channels = ["web", "app", "web", "store", "app", "web"]

# TODO

# %% [markdown]
# ### 題目 3：安全處理壞掉的數量資料
#
# 某批數量資料如下：
# `raw_qty = ["10", "5", "x", "8", "3a", "12"]`
#
# 請完成：
# 1. 用 `try/except` 將可轉換的值轉成整數
# 2. 無法轉換的資料略過
# 3. 最後印出有效數量清單與總和

# %%
raw_qty = ["10", "5", "x", "8", "3a", "12"]

# TODO

# %% [markdown]
# ---
#
# ## Lesson 07｜檔案處理
#
# ### 題目 1：讀取文字檔並計算行數
#
# 請讀取 `../data/source.txt`，完成：
# 1. 計算總行數
# 2. 印出前 3 行內容

# %%
# TODO

# %% [markdown]
# ### 題目 2：把今日分析摘要寫進檔案
#
# 請建立 `daily_summary.txt`，寫入至少 3 行內容，例如：
# - 今日訂單數
# - 今日營收
# - 今日觀察
#
# 完成後再讀回來印出內容。

# %%
# TODO

# %% [markdown]
# ### 題目 3：追加寫入分析日誌
#
# 請建立或追加寫入 `analysis_log.txt`：
# 1. 每次執行都新增一行紀錄
# 2. 內容格式可自訂，例如：`完成 Lesson07 練習`
# 3. 最後印出整份檔案內容

# %%
# TODO

# %% [markdown]
# ---
#
# ## Lesson 08｜模組 module
#
# ### 題目 1：計算平均分數
#
# 請匯入 `statistics` 模組，計算以下評價分數的平均：
# `scores = [4, 5, 3, 4, 5, 5, 4]`

# %%
scores = [4, 5, 3, 4, 5, 5, 4]

# TODO

# %% [markdown]
# ### 題目 2：計算商品折扣後價格
#
# 商品原價 999 元，打 85 折。
#
# 請匯入 `math` 模組，完成：
# 1. 算出折扣後價格
# 2. 使用 `math.floor()` 無條件捨去成整數價格

# %%
# TODO

# %% [markdown]
# ### 題目 3：計算今天和月底還差幾天
#
# 請匯入 `datetime`，自行設定今天日期與月底日期，算出剩幾天。
#
# 情境：做月營收追蹤時，常需要知道離結算還有幾天。

# %%
# TODO

# %% [markdown]
# ---
#
# ## Lesson 09｜OOP 基礎觀念
#
# ### 題目 1：建立簡單訂單類別
#
# 請建立 `Order` 類別：
# - 屬性：`product_name`, `qty`, `unit_price`
# - 方法：`total_amount()`，回傳 `qty * unit_price`
#
# 建立一個實例並測試。
#
# 這題只抓 OOP 最基本觀念即可。

# %%
# TODO

# %% [markdown]
# ---
#
# ## Lesson 11-12｜資料分析入門：pandas + matplotlib
#
# 這一部分改成 3 個題組，每個題組都模擬一段真實分析流程。

# %% [markdown]
# ## 題組 A：讀取與認識訂單資料
#
# 請使用 `../lesson11_12_data/orders.csv` 完成：
# 1. 匯入 `pandas` 為 `pd`
# 2. 讀取 CSV 成為 `df`
# 3. 顯示前 5 筆資料
# 4. 印出 `shape`
# 5. 印出欄位名稱
# 6. 用 `info()` 看資料型別

# %%
# TODO

# %% [markdown]
# ## 題組 B：做每日營收分析
#
# 延續上題的 `df`，完成：
# 1. 把日期欄位轉成日期型別
# 2. 依照日期分組，計算每天總營收
# 3. 找出營收最高的一天
# 4. 算出整體平均每日營收

# %%
# TODO

# %% [markdown]
# ## 題組 C：畫出每日營收圖
#
# 延續上題結果，完成：
# 1. 匯入 `matplotlib.pyplot as plt`
# 2. 畫出每日營收折線圖或長條圖
# 3. 補上標題、X 軸、Y 軸標籤
# 4. 觀察哪幾天營收較高

# %%
# TODO

# %% [markdown]
# ---
#
# ## Lesson 13-14｜pandas 資料清理與 profiling
#
# 這一部分也用 3 個題組，模擬髒資料清理。

# %% [markdown]
# ## 題組 A：先做 profiling
#
# 請使用 `../lesson13_14_pandas/data/dirty_orders.csv` 完成：
# 1. 讀取資料
# 2. 用 `head()`、`tail()`、`sample()` 抽查內容
# 3. 用 `shape` 看大小
# 4. 用 `info()` 看型別與缺值
# 5. 用 `describe(include='all')` 看摘要
# 6. 寫出你觀察到的 3 個資料問題

# %%
# TODO

# %% [markdown]
# ## 題組 B：做基礎清理
#
# 延續上題資料，請完成以下任務：
# 1. 讓日期欄位轉成正確日期格式
# 2. 找出看起來應該是數字、但目前不是數字的欄位
# 3. 嘗試轉型
# 4. 統一 `channel` 欄位大小寫
# 5. 檢查缺值數量

# %%
# TODO

# %% [markdown]
# ## 題組 C：清理後做分析
#
# 請完成：
# 1. 計算每個 `channel` 的訂單數量
# 2. 計算每個 `channel` 的平均訂單金額
# 3. 找出缺值最多的欄位
# 4. 寫一句簡短結論：你覺得這份資料最需要先處理的是什麼

# %%
# TODO

# %% [markdown]
# ---
#
# ## Lesson 15-16｜NumPy 資料分析
#
# 這一部分用 3 個題組練習陣列、遮罩、向量化。

# %% [markdown]
# ## 題組 A：月營收陣列分析
#
# 請匯入 `numpy as np`，建立下列月營收陣列：
# `sales = np.array([120, 135, 128, 150, 160, 175, 168, 180, 190, 200, 210, 230])`
#
# 請完成：
# 1. 印出 `ndim`、`shape`、`dtype`
# 2. 計算平均、總和、最大、最小
# 3. 找出最大值出現在第幾個月

# %%
# TODO

# %% [markdown]
# ## 題組 B：用布林遮罩找出高於平均的月份
#
# 延續上題 `sales`，完成：
# 1. 算出平均營收
# 2. 建立布林遮罩，找出高於平均的值
# 3. 印出這些值
# 4. 算出共有幾個月高於平均

# %%
# TODO

# %% [markdown]
# ## 題組 C：向量化計算成長率
#
# 延續上題 `sales`，完成：
# 1. 計算每個月相較前一個月的差值
# 2. 計算月成長率（可先不乘 100）
# 3. 找出成長最多的一次變化
# 4. 思考：如果不用 NumPy，而改用迴圈，哪裡會變麻煩？

# %%
# TODO

# %% [markdown]
# ---
#
# ## 延伸建議
#
# 如果你要把這份 notebook 再升級，可以繼續做：
# - 再做一份 `solutions.ipynb`
# - 每題加上預期輸出
# - pandas / numpy 題組再加上圖表題
# - 將題目拆成「基礎版」與「挑戰版」
